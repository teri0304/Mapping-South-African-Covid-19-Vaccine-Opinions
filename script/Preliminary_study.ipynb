# %% [markdown]
# ### Determining South African Covid-19 Vaccine Opinions
# Prelimiary Study
# * Import Libaries
# * Retrieve Tweets
# * Preprocess tweets (Data Cleaning)
# * Sentiment Analysis
# * Results
# * Discussion

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import nltk
from nltk import word_tokenize,sent_tokenize
import string
import nltk.corpus
import neattext.functions as nfx
from pandasql import sqldf
import seaborn as sns
from datetime import datetime
import openpyxl

# %%
query = "vaccine South Africa (covid OR vaccine OR ZA OR Gauteng OR Cape OR Town OR Covid19 OR covid19 OR COVID-19 OR Covid-19) (#covid OR #vaccine OR #covid19 OR #COVID-19 OR #Covid-19) until:2022-09-30 since:2020-03-20"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])

# %%
query = "vaccine South Africa (covid OR vaccine OR ZA OR Gauteng OR Cape OR Town OR Covid19 OR covid19 OR COVID-19 OR Covid-19) (#covid OR #vaccine OR #covid19 OR #COVID-19 OR #Covid-19) until:2022-09-30 since:2020-03-20 near:'South Africa'"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])

# %%
df
# Out:
#                         ID                      Date            user  \
# 0      1575565669705207808 2022-09-29 19:18:22+00:00        DIRCO_ZA
# 1      1575445581941686272 2022-09-29 11:21:11+00:00  peoplesvaccine
# 2      1575365820531843075 2022-09-29 06:04:15+00:00     ThiruGeneva
# 3      1575171831002288129 2022-09-28 17:13:24+00:00     VickieRemoe
# 4      1575156860851822593 2022-09-28 16:13:55+00:00  UNICEF_Liberia
# ...                    ...                       ...             ...
# 29680  1241639946437505024 2020-03-22 08:16:46+00:00         rowpolo
# 29681  1241510785031036928 2020-03-21 23:43:31+00:00     okeyezealah
# 29682  1241266354725978112 2020-03-21 07:32:15+00:00      afasirehab
# 29683  1240997816572481545 2020-03-20 13:45:10+00:00         HakiNgo
# 29684  1240969454365945857 2020-03-20 11:52:28+00:00       zimbho263
#
#                              location  \
# 0              Pretoria, South Africa
# 1
# 2
# 3
# 4                Liberia, West Africa
# ...

# %%
query = "vaccine South Africa #covid (South Africa OR covid OR vaccine OR ZA OR Covid19 OR covid19 OR COVID-19 OR Covid-19 OR jab)(#covid OR #vaccine OR #covid19 OR #COVID-19 OR #Covid-19 OR #vaxxed OR #antivax) until:2022-09-30 since:2020-03-20"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df1 = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])

# %%
query = "#IChooseVacciNation (South Africa OR covid OR vaccine OR ZA OR Covid19 OR covid19 OR COVID-19 OR Covid-19 OR jab)(#covid OR #vaccine OR #covid19 OR #COVID-19 OR #Covid-19 OR #vaxxed OR #antivax) until:2022-09-30 since:2020-03-20"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df2 = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])
df2

# %%
query = "#VaccinationRolloutSA (South Africa OR covid OR vaccine OR ZA OR Covid19 OR covid19 OR COVID-19 OR Covid-19 OR jab)(#covid OR #vaccine OR #covid19 OR #COVID-19 OR #Covid-19 OR #vaxxed OR #antivax) until:2022-09-30 since:2020-03-20 near:'South Africa'"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df3 = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])
df3
# Out:
#                      ID                      Date             user  \
# 0   1470744471197396992 2021-12-14 13:16:21+00:00       YHA_Africa
# 1   1444935331929894917 2021-10-04 08:00:03+00:00  VukuzenzeleNews
# 2   1430468305475809286 2021-08-25 09:53:15+00:00     bay_bulletin
# 3   1429813363576610826 2021-08-23 14:30:45+00:00     TheCapeArgus
# 4   1429806423052111873 2021-08-23 14:03:10+00:00              IOL
# 5   1429780153668931585 2021-08-23 12:18:47+00:00      CapeTimesSA
# 6   1429773752552800261 2021-08-23 11:53:21+00:00     TheStar_news
# 7   1429773750531203076 2021-08-23 11:53:20+00:00     TheMercurySA
# 8   1429773408850612224 2021-08-23 11:51:59+00:00     pretorianews
# 9   1429772814861668361 2021-08-23 11:49:37+00:00      DailyNewsSA
# 10  1428714835177574400 2021-08-20 13:45:35+00:00    Totipotent102
# 11  1428417334218264582 2021-08-19 18:03:25+00:00         HealthZA
# 12  1420677266565177347 2021-07-29 09:27:09+00:00  GCIS_Ekurhuleni
# ...

# %%
query = "SA (#COVID19) until:2022-09-30 since:2020-03-20 near:'South Africa'"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df4 = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])
df4
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\2022\October 2022\Preliminary_study.ipynb Cell 8 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> tweets = []
#       <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> limit = 50000
# ----> <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> for tweet in sntwitter.TwitterSearchScraper(query).get_items():
#       <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a>     # print(vars(tweet))
# ...

# %%
query = "SA (#COVID19) until:2022-09-30 since:2020-03-20 near:'South Africa'"
tweets = []
limit = 10

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.id, tweet.date, tweet.user.username,tweet.user.location ,tweet.content, tweet.hashtags])
        
df5 = pd.DataFrame(tweets, columns=['ID','Date', 'user', 'location', 'Tweet', 'Hashtags'])
df5
# Out:
#                     ID                      Date            user  \
# 0  1575556706645352448 2022-09-29 18:42:45+00:00    lansdownecpc
# 1  1575181632377856001 2022-09-28 17:52:21+00:00    lansdownecpc
# 2  1575148721771200512 2022-09-28 15:41:34+00:00  NewsInvasion24
# 3  1574772706809102339 2022-09-27 14:47:25+00:00    lansdownecpc
# 4  1574474393534750720 2022-09-26 19:02:02+00:00    lansdownecpc
# 5  1573978085132754945 2022-09-25 10:09:53+00:00    lansdownecpc
# 6  1573829063973675008 2022-09-25 00:17:43+00:00    MarlizeAndre
# 7  1573010964131512320 2022-09-22 18:06:53+00:00    lansdownecpc
# 8  1572497833680568323 2022-09-21 08:07:53+00:00    lansdownecpc
# 9  1572289301941223424 2022-09-20 18:19:15+00:00    lansdownecpc
#
#           location                                              Tweet  \
# 0                   Praying into South Africa:\nLord in your mercy...
# 1                   Praying into South Africa:\nLord in your mercy...
# ...

# %%
# Out:
# WARNING: You are using pip version 21.2.3; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Users\teris\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_csv('D:/2022/October 2022/tweets.csv')

# %%
q = 'SELECT count(*), user FROM df group by user '

sqldf(q, globals())
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\teris\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#
# File c:\Users\teris\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\default.py:733, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     732 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733     cursor.executemany(statement, parameters)
#
# ...

# %%
tweet_df1 = df1
tweet_df1['UTC']= tweet_df1['Date'].strftime("%m/%d/%Y")
tweet_df1 = tweet_df1.drop(tweet_df1.columns[0], 1)
tweet_df1
#df.drop_duplicates(inplace=True)

# %%
df1.to_excel('D:/2022/October 2022/limited_tweeets.csv')

# %% [markdown]
# Data Cleaning

# %%
tweet_df = df
tweet_df

# %%
tweet_df['hashtags']= tweet_df['Tweet'].apply(nfx.extract_hashtags)
tweet_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\2022\October 2022\Preliminary_study.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> tweet_df['hashtags']= tweet_df['Tweet'].apply(nfx.extract_hashtags)
#       <a href='vscode-notebook-cell:/d%3A/2022/October%202022/Preliminary_study.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> tweet_df
#
# NameError: name 'tweet_df' is not defined

# %%
tweet_df=tweet_df[tweet_df.astype(str)['hashtags'] != '[]']
tweet_df

# %%
tweet_df = tweet_df.reset_index().drop(columns=['index'])

tweet_df['cleaned']= tweet_df['Tweet'].apply(nfx.clean_text)
tweet_df

# %% [markdown]
# ##### Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sid_obj= SentimentIntensityAnalyzer()
print(sid_obj.polarity_scores("#Covid_19SouthAfrica\nThis is very serious"))

# %%
list(sid_obj.polarity_scores("SouthAfrica: No COVID-19 vaccine yet").values())[1]

# %%
tweet_df['Negative']="" 
tweet_df['Neutral']="" 
tweet_df['Positive']="" 
tweet_df['Sentiment_VADER']= ""

# %%
def get_senti(text):
    sentiment = list(sid_obj.polarity_scores(text).values())[3]
    if sentiment > 0:
        sentiment_label = 'Positive'
    elif sentiment < 0:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    result = sentiment_label
    return result

# %%
get_senti("South Africa. New variant, C.1.2, may be more ")

# %%
count = 0

for row in tweet_df['cleaned']:
    
    tweet_df['Negative'][count]= list(sid_obj.polarity_scores(row).values())[0]
    tweet_df['Neutral'][count]= list(sid_obj.polarity_scores(row).values())[1]
    tweet_df['Positive'][count]=list(sid_obj.polarity_scores(row).values())[2]
    count += 1
senti = lambda x : get_senti(x)
tweet_df['Sentiment_VADER'] = tweet_df['cleaned'].apply(senti)

# %%
tweet_df.to_excel('D:/2022/October 2022/Tweets_sentiment.xlsx')

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

stopwords = set(STOPWORDS)

# %%
df.head()
#Checking for NaN values
df.isna().sum()
#Removing NaN Values
df.dropna(inplace = True)
#Creating the text variable
text = " ".join(cat.split()[1] for cat in df['clean text'])

# %%
stop_words = ["covid19", "says", "said", "covid","africa","african","south"] + list(STOPWORDS)

wordcloud = WordCloud(width = 5000, height = 2000, random_state=1, 
                      background_color='white', colormap=sns.color_palette("Blues", as_cmap=True), collocations=False, stopwords = stop_words
                      ).generate(text)



# create coloring from image
plt.figure(figsize=[120,80])
plt.imshow(wordcloud)
plt.axis("off")
# store to file
#plt.savefig("news.png", format="png") 
plt.show()
